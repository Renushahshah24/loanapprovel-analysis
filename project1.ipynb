# %%
import pandas as pd   
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\HP\\Downloads\\Telegram Desktop\\vg_sales_data.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales (in millions)  \
# ...

# %%
# shape of the  dataset
num_rows = df.shape[0]
num_cols = df.shape[1]
print(f"Number of row in dataframe: {num_rows}")
print(f"Number of columns in dataframe:{num_cols}")
# Out:
# Number of row in dataframe: 16598
# Number of columns in dataframe:11

# %%
# information about columns of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        16598 non-null  int64
#  1   Name                        16598 non-null  object
#  2   Platform                    16598 non-null  object
#  3   Year                        16327 non-null  float64
#  4   Genre                       16598 non-null  object
#  5   Publisher                   16540 non-null  object
#  6   NA_Sales (in millions)      16598 non-null  float64
#  7   EU_Sales (in millions)      16598 non-null  float64
#  8   JP_Sales (in millions)      16598 non-null  float64
#  9   Other_Sales (in millions)   16598 non-null  float64
#  10  Global_Sales (in millions)  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
# statistical Description of Numerical data
df.describe()
# Out:
#                Rank          Year  NA_Sales (in millions)  \
# count  16598.000000  16327.000000            16598.000000
# mean    8300.605254   2006.406443                0.264667
# std     4791.853933      5.828981                0.816683
# min        1.000000   1980.000000                0.000000
# 25%     4151.250000   2003.000000                0.000000
# 50%     8300.500000   2007.000000                0.080000
# 75%    12449.750000   2010.000000                0.240000
# max    16600.000000   2020.000000               41.490000
#
#        EU_Sales (in millions)  JP_Sales (in millions)  \
# count            16598.000000            16598.000000
# mean                 0.146652                0.077782
# std                  0.505351                0.309291
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.020000                0.000000
# 75%                  0.110000                0.040000
# ...

# %% [markdown]
# <h3> Crucial Insights from statistical Description</h3>
# <ul>
# <li> The video  games range frome year 1980-2020.</li>
# <li> There are missing values in 'year' columns.</li>
# <li> The rank start from 1 and ends at 16600.( there might be a missing rank as count is 16598)</li>
# </ul>

# %% [markdown]
# <h4>checking for Nulls and Duplicates</h4>

# %%
df.isnull().sum()
# Out:
# Rank                            0
# Name                            0
# Platform                        0
# Year                          271
# Genre                           0
# Publisher                      58
# NA_Sales (in millions)          0
# EU_Sales (in millions)          0
# JP_Sales (in millions)          0
# Other_Sales (in millions)       0
# Global_Sales (in millions)      0
# dtype: int64

# %%
# checking for Duplicate records

print(df.duplicated().sum())
# Out:
# 0

# %%
# checking for duplicate Rank
df['Rank'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h3>Data Cleaning</h3>

# %%
# drop all rows with null values
df.dropna(axis=0,inplace=True)

# %%
# check new shape of dataset after removing nulls
df.shape
# Out:
# (16291, 11)

# %%
df['Name'].nunique()
# Out:
# 11325

# %% [markdown]
# The dataset contains 16291 rows but there exists  only 11325 unique names . this suggest  possible duplicate values exist in our data

# %%
df[['Name','Year']].duplicated().sum()
# Out:
# 4196

# %%
# Removing duplicate  name entries ( since all name should be unique)
df.drop_duplicates(subset='Name',keep='first',inplace=True)

# %%
df.shape
# Out:
# (11325, 11)

# %%
# checking for alphabetic data in Numeric columns

df[['NA_Sales (in millions)','EU_Sales (in millions)','JP_Sales (in millions)','Other_Sales (in millions)',
    'Global_Sales (in millions)']].applymap(np.isreal).all()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14452\313835798.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   'Global_Sales (in millions)']].applymap(np.isreal).all()
# NA_Sales (in millions)        True
# EU_Sales (in millions)        True
# JP_Sales (in millions)        True
# Other_Sales (in millions)     True
# Global_Sales (in millions)    True
# dtype: bool

# %%
# glimpse of the  clean dataset
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales (in millions)  EU_Sales (in millions)  JP_Sales (in millions)  \
# 0                   41.49                   29.02                    3.77
# 1                   29.08                    3.58                    6.81
# 2                   15.85                   12.88                    3.79
# 3                   15.75                   11.01                    3.28
# 4                   11.27                    8.89                   10.22
#
#    Other_Sales (in millions)  Global_Sales (in millions)
# ...

# %% [markdown]
# <h3> Data Visualization</h3>

# %%
# creating list of numeric columns with year excluded

numeric_cols = df.select_dtypes(include=['float64']).columns.to_list()[1:]
numeric_cols
# Out:
# ['NA_Sales (in millions)',
#  'EU_Sales (in millions)',
#  'JP_Sales (in millions)',
#  'Other_Sales (in millions)',
#  'Global_Sales (in millions)']

# %%
# distribution of sales data

fig, axes = plt.subplots(2,3, figsize=(15,10))
color = []
n = 0
for i in range (2):
    for j in range (3):
        if n>4:
            break
        sns.boxenplot(df[numeric_cols[n]], fill=True, ax=axes[i,j])
        axes[i,j].set_title(f"{numeric_cols[n]}")
        n+=1
plt.show()

# %%
sns.heatmap(df[numeric_cols].corr(numeric_only=True),annot=True)
plt.title("Sales Correlation Heatmap",fontdict={'size' :16})
plt.xticks(rotation=80, size=20)
plt.show()

# %% [markdown]
# <h3> What are the Top 10 Game Publications globlly?</h3>

# %%
# Publisher with highest sales in NA regian
top10_publish = df.groupby('Publisher')['Global_Sales (in millions)'].sum().sort_values(ascending=False)[:10]

# %%
plt.pie(top10_publish.values,labels=top10_publish.index, autopct="%.2f",colors= plt.get_cmap('Set2').colors)
plt.title("Biggest Publisher in the video game industry",fontdict={'weight':'bold'})
plt.legend(bbox_to_anchor=(1.4,1.1))
plt.show()

# %%
top10_publish = df.groupby('Publisher')['Global_Sales (in millions)'].sum().sort_values(ascending=False)[:10]

# %%
for i in numeric_cols:
    top10_publish = df.groupby('Publisher')[i].sum().sort_values(ascending=False)[:10]    
    plt.pie(top10_publish.values,labels=top10_publish.index, autopct="%.2f",colors= plt.get_cmap('Set2').colors)
    plt.title(f"Biggest Name in the video game industry {i}",fontdict={'weight':'bold'})
    plt.legend(bbox_to_anchor=(1.4,1.1))
    plt.show()

# %% [markdown]
# <h3> Which publication has realeased the most number of Game?</h3>

# %%
top10_numofgames = df['Publisher'].value_counts().sort_values(ascending=False)[:10]

# %%
colors= plt.cm.brg(np.linspace(0,1, len(top10_numofgames.index)))
bars = plt.bar(top10_numofgames.index,top10_numofgames.values,color=colors)
plt.xticks(rotation=90)
ax = plt.gca()   # Get the current axes
xticks = ax.get_xticklabels()
for tick, color in zip(xticks, colors): 
    tick.set_color(color)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height}',
             ha='center', va='bottom',fontsize=10,color='navy') 
plt.title("Top 10 Publitions by no. of Games realesed", fontdict={'weight':'bold'},color="tab:blue")  
plt.show()

# %% [markdown]
# <h3>

# %% [markdown]
# <h3> which Video Game had The Most Sales ? </h3>

# %%
top_10_vg = df.sort_values(by='Global_Sales (in millions)', ascending=False)[:10]

# %%
plt.barh(top_10_vg['Name'].values[::-1],top_10_vg['Global_Sales (in millions)'].values[::-1],color='purple')
plt.title("Top Selling video Game of Past 4 Decates")
plt.show()

# %% [markdown]
# <h3> Most successful Game of Each Year (Creation year)</h3>

# %%
best_each_year = df.loc[df.groupby('Year')['Global_Sales (in millions)'].idxmax()]
best_each_year
# Out:
#         Rank                                              Name Platform  \
# 258      259                                         Asteroids     2600
# 239      240                                          Pitfall!     2600
# 89        90                                           Pac-Man     2600
# 421      422                                          Baseball      NES
# 9         10                                         Duck Hunt      NES
# 1          2                                 Super Mario Bros.      NES
# 127      128                               The Legend of Zelda      NES
# 251      252                   Zelda II: The Adventure of Link      NES
# 22        23                               Super Mario Bros. 3      NES
# 5          6                                            Tetris       GB
# 18        19                                 Super Mario World     SNES
# 231      232           The Legend of Zelda: A Link to the Past     SNES
# ...

# %%
colors = plt.cm.viridis(np.linspace(0,1, len(best_each_year['Year'].values)))
plt.figure(figsize=(14,15))
bars =plt.bar(best_each_year['Year'].values, best_each_year['Global_Sales (in millions)'].values,color=colors)
n = 0
for bar in bars:
    x = bar.get_x()
    y = bar.get_height()
    plt.text(x+0.5, y+0.5, best_each_year['Name'].values[n],ha='center',va='bottom',rotation=90)
    n+=1
plt.title("Most successful Game(Frome each year)", pad=20) 
plt.show()

# %% [markdown]
# <h3> Video Games by Genre</h3>

# %%
games_genre = df['Genre'].value_counts()

# %%
colors = plt.cm.cool(np.linspace(0,1, len(games_genre.index)))
explode = tuple(0.01 for i in range (12))
plt.pie(games_genre.values,labels=games_genre.index,autopct='%.2f',colors=colors,pctdistance=0.85,explode=explode)
centre_circle = plt.Circle((0, 0),0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("Video Game by genre")
plt.show()

# %%
#### we have to remove this before  submition the project. 

colors = plt.cm.cool(np.linspace(0,1, len(games_genre.index)))
explode = tuple(0.01 for i in range (12))
plt.pie(games_genre.values,labels=games_genre.index,autopct='%.2f',colors=colors,pctdistance=0.85,explode=explode,
     wedgeprops={'width':0.3}   )
#centre_circle = plt.Circle((0, 0),0.70, fc='white')
#fig = plt.gcf()
#fig.gca().add_artist(centre_circle)
plt.title("Video Game by genre")
plt.show()

# %% [markdown]
# <h3> Conclusion</h3>

# %%
# Top 5 best selling generes
sales_genre = df.groupby('Genre')['Global_Sales (in millions)'].sum().sort_values(ascending=False)
sales_genre
# Out:
# Genre
# Action          1135.45
# Sports           941.86
# Role-Playing     810.17
# Shooter          708.81
# Platform         704.76
# Misc             644.50
# Racing           589.14
# Fighting         349.51
# Simulation       346.67
# Puzzle           219.03
# Adventure        199.47
# Strategy         160.30
# Name: Global_Sales (in millions), dtype: float64

# %%
explode=(0.08,0.08,0.08,0.08,0.08)

fig, ax = plt.subplots()
fig.patch.set_facecolor('black')
ax.pie(sales_genre.values[:5],labels=sales_genre.index[:5],autopct='%.2f',explode=explode,textprops={'color':'white'})

plt.title("Top 5 Best selling video game")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
fig.patch.set_facecolor('green')  # Set the figure's background color
ax.set_facecolor('white')         # Set the axes' (plot area) background color

# Plotting the top 5 best-selling video game genres
ax.bar(sales_genre.index[:5], sales_genre.values[:5], color='red', width=0.5)

plt.title("Top 5 Best Selling Video Game Genres")
plt.xlabel("Genre")
plt.ylabel("Sales")
plt.show()

# %%
top5_platform = df['Platform'].value_counts()[:5]

# %%
plt.bar(top5_platform.index, top5_platform.values, color=['Green','orange','red','purple','cyan'])
plt.title("Top 5Platform (Device)")
plt.show()

# %% [markdown]
# <h3>Conclusions</h3>

# %% [markdown]
# 1.Wii Spots is the top seller in the gaming industry with 82.74 million copies sold.
# 2.Nintendo is the  world's leading game publisher.
# 3.PS2 is the most utilosed gaming device(platform).
# 4.Action is the most preferred genre among gamers (accumulating 26% of the total sales).
